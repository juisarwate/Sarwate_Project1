# %%
# !pip install plotnine
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting plotnine
#   Using cached plotnine-0.8.0-py3-none-any.whl (4.7 MB)
# Collecting mizani>=0.7.3
#   Using cached mizani-0.7.3-py3-none-any.whl (63 kB)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.9/site-packages (from plotnine) (1.3.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.9/site-packages (from plotnine) (1.21.2)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.9/site-packages (from plotnine) (3.4.3)
# Collecting descartes>=1.1.0
#   Using cached descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Collecting patsy>=0.5.1
#   Using cached patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Collecting scipy>=1.5.0
#   Downloading scipy-1.7.3-cp39-cp39-macosx_10_9_x86_64.whl (33.2 MB)
#      |████████████████████████████████| 33.2 MB 68 kB/s
# Collecting statsmodels>=0.12.1
#   Downloading statsmodels-0.13.1-cp39-cp39-macosx_10_15_x86_64.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 480 kB/s
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.1->plotnine) (8.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.1->plotnine) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.1->plotnine) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.1->plotnine) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib>=3.1.1->plotnine) (2.4.7)
# Collecting palettable
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas>=1.1.0->plotnine) (2021.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Installing collected packages: scipy, patsy, palettable, statsmodels, mizani, descartes, plotnine
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed descartes-1.1.0 mizani-0.7.3 palettable-3.3.0 patsy-0.5.2 plotnine-0.8.0 scipy-1.7.3 statsmodels-0.13.1

# %%
import pandas as pd
from plotnine import *

# %%
df = pd.read_csv('Visitation_by_Month.csv')
# df = pd.read_csv('2021_Current_Year_Monthly_and_Annual_Summary_Report_%281979%2D_Present%29.csv')
# Columns don't have headings
df.head(10)
# Out:
#    Year      JAN      FEB      MAR      APR      MAY      JUN      JUL  \
# 0  2020  132,742  167,778   92,324        0        0  236,534  501,068
# 1  2019  116,746  111,665  173,610  297,207  393,004  496,625  717,462
# 2  2018  129,432  143,321  170,681  278,349  385,670  543,690  504,230
# 3  2017  120,025  119,421  166,793  302,553  471,844  565,702  633,351
# 4  2016  139,780  201,601  286,990  305,092  457,309  703,614  780,728
# 5  2015  128,318  135,316  194,667  281,328  408,121  545,231  626,009
# 6  2014  112,133  113,403  146,750  242,722  333,308  496,363  623,663
# 7  2013  103,910  114,440  165,409  231,178  370,422  508,941  611,538
# 8  2012  120,496  113,341  136,687  243,102  356,500  528,186  623,101
# 9  2011  100,718   93,588  100,433  231,372  356,588  503,741  704,553
#
#        AUG      SEP      OCT      NOV      DEC
# 0  375,226  258,561  249,827  136,799  117,454
# 1  703,153  584,664  448,939  230,598  149,188
# 2  441,867  524,387  360,776  215,854  311,179
# 3  615,892  566,279  429,827  217,927  127,276
# 4  692,450  598,428  483,232  218,998  160,646
# 5  636,936  527,402  357,223  169,425  140,241
# 6  654,157  467,205  354,769  203,678  134,491
# 7  552,137  460,855  279,526  161,356  131,479
# 8  660,118  482,004  322,687  141,868  125,314
# 9  699,749  533,502  360,449  139,079  127,621

# %%
df.info()
# Need to make months columns into int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            42 non-null     int64
#  1   JAN                             42 non-null     object
#  2   FEB                             42 non-null     object
#  3   MAR                             42 non-null     object
#  4   APR                             42 non-null     object
#  5   MAY                             42 non-null     object
#  6   JUN                             42 non-null     object
#  7   JUL                             42 non-null     object
#  8   AUG                             42 non-null     object
#  9   SEP                             42 non-null     object
#  10  OCT                             42 non-null     object
#  11  NOV                             42 non-null     object
#  12  DEC                             42 non-null     object
#  13  total_yearly_visitors_Yosemite  42 non-null     object
# dtypes: int64(1), object(13)
# memory usage: 4.7+ KB

# %%
# months = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
# df['total_yearly_visitors_Yosemite'] = df[months].sum(axis=1)
# df.head()

# %%
# Sort Year and then each month
# Will I need to remake the table to get this?

# %%
ggplot(df) + aes(x='Year', y='JAN') + geom_bar(stat='identity')
# Somethings wrong with the values in the y-axis, need to make int
# Out:
# <ggplot: (302890045)>

# %%
df1 = pd.read_csv('Visitation_By_State_and_By_Park_%282017%2D_LastCalendarYear%29.csv')
df1.head()
# Out:
#      State                     Field1   Field2 Textbox22   Field4 Textbox24  \
# 0  Alabama         Horseshoe Bend NMP   28,600   -36.97%    8,788   -25.20%
# 1  Alabama  Little River Canyon NPRES  802,375    23.44%  168,827    27.60%
# 2  Alabama         Natchez Trace PKWY  428,736    -2.72%  143,413    -3.01%
# 3  Alabama            Russell Cave NM    8,462   -49.15%    1,074   -55.36%
# 4  Alabama        Tuskegee Airmen NHS    6,843   -77.26%      855   -77.27%
#
#   TotalNonRecreationVisits Textbox98 TotalRecreationVisitorHours Textbox103  \
# 0                        0       NaN                     105,461    -25.20%
# 1                        0       NaN                   2,025,934     27.60%
# 2                  583,028    -9.08%                   1,720,966     -3.01%
# 3                        0       NaN                      12,894    -55.35%
# 4                        0       NaN                      10,264    -77.26%
#
#    ...  Textbox47 Textbox129  Textbox42 Textbox135  Textbox37 Textbox141  \
# 0  ...  1,883,220        NaN  1,459,486        NaN  1,434,938        NaN
# 1  ...  1,883,220        NaN  1,459,486        NaN  1,434,938        NaN
# 2  ...  1,883,220        NaN  1,459,486        NaN  1,434,938        NaN
# 3  ...  1,883,220        NaN  1,459,486        NaN  1,434,938        NaN
# 4  ...  1,883,220        NaN  1,459,486        NaN  1,434,938        NaN
#
#   Textbox95 Textbox146 Textbox90 Textbox153
# 0    30,708        NaN   906,939        NaN
# 1    30,708        NaN   906,939        NaN
# 2    30,708        NaN   906,939        NaN
# 3    30,708        NaN   906,939        NaN
# 4    30,708        NaN   906,939        NaN
#
# [5 rows x 75 columns]

# %%
ggplot(df1) + aes(x='Field1', y='TotalRecreationVisitorHours') + geom_bar(stat='identity')
# Out:
# <ggplot: (303225061)>

# %%
ggplot(df1) + aes(x='State', y='TotalRecreationVisitorHours') + geom_bar(stat='identity')
# Out:
# <ggplot: (303171645)>
